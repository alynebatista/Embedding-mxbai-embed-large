# %%
#!pip install langchain_community

# %%
from langchain_community.embeddings import OllamaEmbeddings

# Define o modelo
embeddings = OllamaEmbeddings(model="mxbai-embed-large")

# Define a frase a ser usada
query = "Bonito é melhor que feio. Explícito é melhor que implícito."

# Calcula os embeddings
query_embedding = embeddings.embed_query(query)

# Exibe os Embeddings
print(query_embedding)

# Calcula e exibe o tamanho do embedding
embedding_size = len(query_embedding)
print(f"Tamanho dos embeddings: {embedding_size}")
# Out:
# C:\Users\alyne\AppData\Local\Temp\ipykernel_3236\322703618.py:4: LangChainDeprecationWarning: The class `OllamaEmbeddings` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the `langchain-ollama package and should be used instead. To use it run `pip install -U `langchain-ollama` and import as `from `langchain_ollama import OllamaEmbeddings``.
#   embeddings = OllamaEmbeddings(model="mxbai-embed-large")
# ...
